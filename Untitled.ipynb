# %%
import os 
import pathlib 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import random
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
from sklearn.metrics import classification_report,confusion_matrix

# %%
for dirpath,dirnames,filenames in os.walk("C:/Users/pc/Project/COVID_IEEE"):
    print(f"there are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# there are 2 directories and 0 images in 'C:/Users/pc/Project/COVID_IEEE'.
# there are 0 directories and 536 images in 'C:/Users/pc/Project/COVID_IEEE\covid'.
# there are 0 directories and 668 images in 'C:/Users/pc/Project/COVID_IEEE\normal'.

# %%
data_dir = pathlib.Path("C:/Users/pc/Project/COVID_IEEE")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
class_names
# Out:
# array(['covid', 'normal'], dtype='<U6')

# %%
def view_image(target_dir, target_class):
    target_folder = target_dir+target_class
    random_image = random.sample(os.listdir(target_folder),1)
    print(random_image)
    img = mpimg.imread(target_folder+"/"+ random_image[0])
    plt.imshow(img, cmap ="gray")
    plt.title(target_class)
    plt.axis("off")
    print(f"image shape {img.shape}")
    
    return img

# %%
img = view_image("C:/Users/pc/Project/COVID_IEEE/","covid")
# Out:
# ['ryct.2020200034.fig5-day0.jpeg']
# image shape (1333, 1118, 3)

# %%
img = view_image("C:/Users/pc/Project/COVID_IEEE/","normal")
# Out:
# ['NORMAL2-IM-0922-0001.jpeg']
# image shape (1140, 1508)

# %%
data=[]
labels=[]
covid=os.listdir("C:/Users/pc/Project/COVID_IEEE/covid/")
for a in covid:

    image = cv2.imread("C:/Users/pc/Project/COVID_IEEE/covid/"+a,)
    image = cv2.resize(image, (224, 224))


    data.append(image)
    labels.append(0)

# %%
normal=os.listdir("C:/Users/pc/Project/COVID_IEEE/normal/")
for a in normal:

    image = cv2.imread("C:/Users/pc/Project/COVID_IEEE/normal/"+a,)
    image = cv2.resize(image, (224, 224))



    data.append(image)
    labels.append(1)

# %%
data = np.array(data) / 255.0
img_labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, img_labels, test_size=0.20, random_state=10)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %%
epochs=10

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[224,224,3], weights = "imagenet", include_top=False)

for layer in base_model.layers:
  layer.trainable =False
# Out:
# ...
# 9406464/9406464 [==============================] - 5s 1us/step

# %%
mobile_netV2_model = Flatten()(base_model.output)

mobile_netV2_model = Dense(units=1024, activation="relu")(mobile_netV2_model)
mobile_netV2_model = Dense(units=512, activation="relu")(mobile_netV2_model)
mobile_netV2_model = Dense(units=256, activation="relu")(mobile_netV2_model)

prediction_layer = Dense(units=2, activation="softmax")(mobile_netV2_model)

# %%
mobile_netV2_model = Model(inputs = base_model.input, outputs = prediction_layer)
mobile_netV2_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
mobile_netV2_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
history=mobile_netV2_model.fit(X_train, y_train, validation_split=0.3, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 22/22 [==============================] - 64s 2s/step - loss: 4.0097 - accuracy: 0.9154 - val_loss: 1.1531 - val_accuracy: 0.9689
# Epoch 2/10
# 22/22 [==============================] - 34s 2s/step - loss: 0.1672 - accuracy: 0.9896 - val_loss: 0.5308 - val_accuracy: 0.9827
# Epoch 3/10
# 22/22 [==============================] - 37s 2s/step - loss: 0.2704 - accuracy: 0.9970 - val_loss: 0.5699 - val_accuracy: 0.9862
# Epoch 4/10
# 22/22 [==============================] - 37s 2s/step - loss: 0.1800 - accuracy: 0.9896 - val_loss: 0.3886 - val_accuracy: 0.9896
# Epoch 5/10
# 22/22 [==============================] - 40s 2s/step - loss: 0.3587 - accuracy: 0.9911 - val_loss: 0.5276 - val_accuracy: 0.9896
# Epoch 6/10
# 22/22 [==============================] - 37s 2s/step - loss: 0.0210 - accuracy: 0.9985 - val_loss: 0.6664 - val_accuracy: 0.9896
# Epoch 7/10
# ...

# %%
mobile_netV2_model.evaluate(X_test,y_test)
# Out:
# 8/8 [==============================] - 22s 867ms/step - loss: 1.1447 - accuracy: 0.9751
# [1.1446874141693115, 0.9751037359237671]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(16,5))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.title('Training and Validation Loss')
plt.show()

# %%
y_pred=mobile_net_model.predict(X_test)
# Out:
# 8/8 [==============================] - 19s 810ms/step

# %%
Y_pred=[]
for i in y_pred:
    if i[0]>i[1]:
        Y_pred.append(0)
    else:
        Y_pred.append(1)

# %%
Y_test=[]
for i in y_test:
    if i[0]>i[1]:
        Y_test.append(0)
    else:
        Y_test.append(1)

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       118
#            1       0.96      0.99      0.98       123
#
#     accuracy                           0.98       241
#    macro avg       0.98      0.97      0.98       241
# weighted avg       0.98      0.98      0.98       241

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=Y_test,predictions=Y_pred)

plt.figure(figsize = (8,5))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
tp = cm[0][0]
fp = cm[0][1]
fn = cm[1][0]
tn = cm[1][1]

# %%
sensitivity=(tp/(tp+fn))
print("The sensitivity is","{:.2f}".format(sensitivity*100),"%")
# Out:
# The sensitivity is 100.00 %

# %%
specificity=(tn/(tn+fp))
print("The specificity is","{:.2f}".format(specificity*100),"%")
# Out:
# The specificity is 96.09 %
